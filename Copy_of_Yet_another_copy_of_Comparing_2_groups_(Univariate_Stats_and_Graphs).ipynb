# %% [markdown]
# <a href="https://colab.research.google.com/github/kyik1/Math-200/blob/main/Copy_of_Yet_another_copy_of_Comparing_2_groups_(Univariate_Stats_and_Graphs).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
link = 'https://raw.githubusercontent.com/smarika0724/math200/refs/heads/main/Survey%20for%20the%20students%20%20(Responses)%20-%20Form%20Responses%201%20(1).csv'

df = pd.read_csv(link)
df.head()
# Out:
#                   RR               Email Address  Score  employed work_status  \
# 0  4/9/2025 10:54:47       k3oangelina@gmail.com    NaN       Yes   Part-time
# 1  4/9/2025 10:55:00    zjeees20061006@gmail.com    NaN       Yes   Part-time
# 2  4/9/2025 10:55:08       apeeples@my.smccd.edu    NaN       Yes   Part-time
# 3  4/9/2025 10:55:33  jenniferavila909@gmail.com    NaN       Yes   Full-time
# 4  4/9/2025 10:55:35        ruedad1@my.smccd.edu    NaN       Yes   Part-time
#
#    credit  study_hours
# 0     6.0            6
# 1    12.0            0
# 2    17.0            1
# 3     6.0            2
# 4    16.0            2

# %%
df = pd.read_csv(link)
df
# Out:
#                     RR                   Email Address  Score  employed  \
# 0    4/9/2025 10:54:47           k3oangelina@gmail.com    NaN       Yes
# 1    4/9/2025 10:55:00        zjeees20061006@gmail.com    NaN       Yes
# 2    4/9/2025 10:55:08           apeeples@my.smccd.edu    NaN       Yes
# 3    4/9/2025 10:55:33      jenniferavila909@gmail.com    NaN       Yes
# 4    4/9/2025 10:55:35            ruedad1@my.smccd.edu    NaN       Yes
# 5    4/9/2025 10:56:06        zjeees20061006@gmail.com    NaN        No
# 6    4/9/2025 10:59:02         iglesiasj1@my.smccd.edu    NaN       Yes
# 7    4/9/2025 11:02:46           bustosb1@my.smccd.edu    NaN       Yes
# 8    4/9/2025 11:09:54       venturacabk1@my.smccd.edu    NaN       Yes
# 9    4/9/2025 12:02:59             shtwe2@my.smccd.edu    NaN        No
# 10   4/9/2025 12:04:16              ahtun@my.smccd.edu    NaN        No
# 11   4/9/2025 12:43:47              jhtun@my.smccd.edu    NaN        No
# ...

# %%
df
# Out:
#                     RR                   Email Address  Score  employed  \
# 0    4/9/2025 10:54:47           k3oangelina@gmail.com    NaN       Yes
# 1    4/9/2025 10:55:00        zjeees20061006@gmail.com    NaN       Yes
# 2    4/9/2025 10:55:08           apeeples@my.smccd.edu    NaN       Yes
# 3    4/9/2025 10:55:33      jenniferavila909@gmail.com    NaN       Yes
# 4    4/9/2025 10:55:35            ruedad1@my.smccd.edu    NaN       Yes
# 5    4/9/2025 10:56:06        zjeees20061006@gmail.com    NaN        No
# 6    4/9/2025 10:59:02         iglesiasj1@my.smccd.edu    NaN       Yes
# 7    4/9/2025 11:02:46           bustosb1@my.smccd.edu    NaN       Yes
# 8    4/9/2025 11:09:54       venturacabk1@my.smccd.edu    NaN       Yes
# 9    4/9/2025 12:02:59             shtwe2@my.smccd.edu    NaN        No
# 10   4/9/2025 12:04:16              ahtun@my.smccd.edu    NaN        No
# 11   4/9/2025 12:43:47              jhtun@my.smccd.edu    NaN        No
# ...

# %%
df = pd.read_csv(link)
df
# Out:
#                     RR                   Email Address  Score  employed  \
# 0    4/9/2025 10:54:47           k3oangelina@gmail.com    NaN       Yes
# 1    4/9/2025 10:55:00        zjeees20061006@gmail.com    NaN       Yes
# 2    4/9/2025 10:55:08           apeeples@my.smccd.edu    NaN       Yes
# 3    4/9/2025 10:55:33      jenniferavila909@gmail.com    NaN       Yes
# 4    4/9/2025 10:55:35            ruedad1@my.smccd.edu    NaN       Yes
# 5    4/9/2025 10:56:06        zjeees20061006@gmail.com    NaN        No
# 6    4/9/2025 10:59:02         iglesiasj1@my.smccd.edu    NaN       Yes
# 7    4/9/2025 11:02:46           bustosb1@my.smccd.edu    NaN       Yes
# 8    4/9/2025 11:09:54       venturacabk1@my.smccd.edu    NaN       Yes
# 9    4/9/2025 12:02:59             shtwe2@my.smccd.edu    NaN        No
# 10   4/9/2025 12:04:16              ahtun@my.smccd.edu    NaN        No
# 11   4/9/2025 12:43:47              jhtun@my.smccd.edu    NaN        No
# ...

# %%
df = pd.read_csv
df = pd.read_csv(link)
df
# Frequency and percentage table
employed_counts = df[' employed'].value_counts()
employed_percent = df[' employed'].value_counts(normalize=True) * 100

# Display as a DataFrame
employed_table = pd.DataFrame({
    'Count': employed_counts,
    'Percentage': employed_percent.round(1)
})

print(employed_table)
print(type(df))
# Out:
#            Count  Percentage
#  employed
# Yes           39        65.0
# No            21        35.0
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv
df = pd.read_csv(link)
df
# Frequency and percentage table
employed_counts = df[' employed'].value_counts().plot(kind='bar')
employed_percent = df[' employed'].value_counts(normalize=True) * 100

# %%
df = pd.read_csv
df = pd.read_csv(link)
df
# Frequency and percentage table
employed_counts = df[' employed'].value_counts().plot(kind='pie')
employed_percent = df[' employed'].value_counts(normalize=True) * 100

# %%
# Get frequency counts and percentages
employed_freq = df['employed'].value_counts()
employed_percent = df['employed'].value_counts(normalize=True) * 100

# Create a DataFrame with both frequency and percentage
employed_table = pd.DataFrame({
    'Frequency': employed_freq,
    'Percentage': employed_percent.round(2)  # Round percentages to 2 decimal places
})

# Add a % symbol to the percentage values
employed_table['Percentage'] = employed_table['Percentage'].astype(str) + '%'

print("\nEmployment Status Distribution:")
print(employed_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'employed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-374d1c5cba07> in <cell line: 0>()
#       1 # Get frequency counts and percentages
# ...

# %%
df = pd.read_csv
df = pd.read_csv(link)
df
# Frequency and percentage table
study_hours_counts = df['study_hours'].value_counts()
study_hours_counts_percent = df['study_hours'].value_counts(normalize=True) * 100

# Display as a DataFrame
study_hours_counts_table = pd.DataFrame({
    'Count': study_hours_counts,
    'Percentage': study_hours_counts_percent.round(1)
})

print(study_hours_counts_table)
print(type(df))
# Out:
#              Count  Percentage
# study_hours
# 20              11        18.3
# 5                9        15.0
# 2                7        11.7
# 14               5         8.3
# 10               5         8.3
# 0                4         6.7
# 6                3         5.0
# 8                3         5.0
# 15               3         5.0
# 1                2         3.3
# 7                2         3.3
# 18               2         3.3
# 16               2         3.3
# 12               1         1.7
# 3                1         1.7
# <class 'pandas.core.frame.DataFrame'>

# %%
df = pd.read_csv
df = pd.read_csv(link)
df
# Frequency and percentage table
study_hours_counts = df['study_hours'].value_counts().plot(kind='bar')
study_hours_counts_percent = df['study_hours'].value_counts(normalize=True) * 100

# %%
df = pd.read_csv
df = pd.read_csv(link)
df
# Frequency and percentage table
study_hours_counts = df['study_hours'].value_counts().plot(kind='pie')
study_hours_counts_percent = df['study_hours'].value_counts(normalize=True) * 100

# %% [markdown]
# ## Univariate Statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Frequency and percentage table for study_hours
study_hours_counts = df['study_hours'].value_counts().sort_index()
study_hours_percent = df['study_hours'].value_counts(normalize=True).sort_index() * 100

# Display as a DataFrame
study_hours_table = pd.DataFrame({
    'Count': study_hours_counts,
    'Percentage': study_hours_percent.round(1)
})
print(study_hours_table)

# Histogram for study_hours
plt.figure(figsize=(8, 5))
sns.histplot(df['study_hours'], bins=10, kde=False, color='skyblue', edgecolor='black')
plt.title('Histogram of Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#              Count  Percentage
# study_hours
# 0                4         6.7
# 1                2         3.3
# 2                7        11.7
# 3                1         1.7
# 5                9        15.0
# 6                3         5.0
# 7                2         3.3
# 8                3         5.0
# 10               5         8.3
# 12               1         1.7
# 14               5         8.3
# 15               3         5.0
# 16               2         3.3
# 18               2         3.3
# 20              11        18.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Frequency and percentage table for study_hours
study_hours_counts = df['study_hours'].value_counts().sort_index()
study_hours_percent = df['study_hours'].value_counts(normalize=True).sort_index() * 100

# Create a Histogram for study_hours
plt.figure(figsize=(8, 5))
sns.histplot(df['study_hours'], bins=15, kde=True, color='skyblue', edgecolor='black')
plt.title('Histogram of Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.boxplot(data=df, y='study_hours')
# Out:
# <Axes: ylabel='study_hours'>

# %%
df.groupby('work_status')['study_hours'].describe()
# Out:
#              count       mean       std   min   25%   50%    75%   max
# work_status
# Full-time     13.0   9.692308  6.638080   0.0   5.0  10.0  14.00  20.0
# Not working    3.0  17.333333  2.309401  16.0  16.0  16.0  18.00  20.0
# Part-time     24.0   8.125000  7.060684   0.0   2.0   6.5  11.25  20.0
# not working   20.0  10.600000  6.808663   2.0   5.0  10.0  15.75  20.0

# %%
import pandas as pd

# Frequency and percentage table for work_status
work_status_counts = df['work_status'].value_counts()
work_status_percent = df['work_status'].value_counts(normalize=True) * 100

# Combine into a DataFrame
work_status_table = pd.DataFrame({
    'Count': work_status_counts,
    'Percentage': work_status_percent.round(1)
})

# Display the table
print(work_status_table)
# Out:
#              Count  Percentage
# work_status
# Part-time       24        40.0
# not working     20        33.3
# Full-time       13        21.7
# Not working      3         5.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Frequency and percentage table for work_status
work_status_counts = df['work_status'].value_counts()
work_status_percent = df['work_status'].value_counts(normalize=True) * 100

# Combine into a DataFrame
work_status_table = pd.DataFrame({
    'Count': work_status_counts,
    'Percentage': work_status_percent.round(1)
})

# Display the table
print(work_status_table)

# Plot pie chart
plt.figure(figsize=(6, 6))
work_status_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=plt.cm.Pastel1.colors)
plt.title('Work Status Distribution')
plt.ylabel('')  # Hide y-label
plt.tight_layout()
plt.show()
# Out:
#              Count  Percentage
# work_status
# Part-time       24        40.0
# not working     20        33.3
# Full-time       13        21.7
# Not working      3         5.0

# %%
plt.figure(figsize=(8, 5))
work_status_counts.plot(kind='bar', color=plt.cm.Pastel1.colors)
plt.title('Work Status Distribution')
plt.xlabel('Work Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df['work_status'].describe()
# Out:
# count            60
# unique            4
# top       Part-time
# freq             24
# Name: work_status, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is already loaded with your data

# Create a Violin Plot for study_hours
plt.figure(figsize=(8, 5))
sns.violinplot(x=df['study_hours'], color='skyblue', edgecolor='black')
plt.title('Violin Plot of Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Create a Dot Plot for study_hours
plt.figure(figsize=(8, 5))
sns.stripplot(x=df['study_hours'], color='skyblue', jitter=True, size=7)
plt.title('Dot Plot of Study Hours')
plt.xlabel('Study Hours')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Frequency and percentage table for study_hours
study_hours_counts = df['study_hours'].value_counts().sort_index()
study_hours_percent = df['study_hours'].value_counts(normalize=True).sort_index() * 100

# Display the frequency and percentage table
study_hours_table = pd.DataFrame({
    'Count': study_hours_counts,
    'Percentage': study_hours_percent.round(1)
})
print(study_hours_table)

# Create a boxplot for study_hours
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['study_hours'], color='skyblue', edgecolor='black')
plt.title('Boxplot of Study Hours')
plt.ylabel('Study Hours')  # Label for the vertical axis
plt.xlabel('')  # No need for x-axis label in a boxplot
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid for y-axis for better clarity
plt.tight_layout()  # Adjust layout to avoid clipping
plt.show()
# Out:
#              Count  Percentage
# study_hours
# 0                4         6.7
# 1                2         3.3
# 2                7        11.7
# 3                1         1.7
# 5                9        15.0
# 6                3         5.0
# 7                2         3.3
# 8                3         5.0
# 10               5         8.3
# 12               1         1.7
# 14               5         8.3
# 15               3         5.0
# 16               2         3.3
# 18               2         3.3
# 20              11        18.3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a61dcdbbd2d8> in <cell line: 0>()
#      16 # Create a boxplot for study_hours
#      17 plt.figure(figsize=(8, 5))
# ---> 18 sns.boxplot(y=df['study_hours'], color='skyblue', edgecolor='black')
#      19 plt.title('Boxplot of Study Hours')
# ...

# %%
import pandas as pd

# Assuming 'df' is your DataFrame and 'employed' is the column
employed_counts = df['work_status'].value_counts()
employed_percent = df['work_status'].value_counts(normalize=True) * 100

# Combine into a single DataFrame
employed_table = pd.DataFrame({
    'Count': employed_counts,
    'Percentage': employed_percent.round(1)
})

print(employed_table)

# %%
df.describe()

# %%
pip install researchpy

# %%
# Install required libraries (if running in Colab)
# !pip install pandas seaborn matplotlib --quiet

# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset (replace this with your actual data)
df_data = {
    'EmploymentStatus': ['Employed', 'Employed', 'Unemployed', 'Unemployed', 'Employed', 'Unemployed', 'Employed', 'Unemployed'],
    'StudyHoursCategory': ['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Medium', 'Medium']
}

df = pd.DataFrame(data)

# Frequency table (cross-tabulation)
freq_table = pd.crosstab(df['EmploymentStatus'], df['StudyHoursCategory'])
print("Frequency Table:\n")
print(freq_table)

# Bar plot
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='StudyHoursCategory', hue='EmploymentStatus')
plt.title('Study Hours by Employment Status')
plt.xlabel('Study Hours Category')
plt.ylabel('Count')
plt.legend(title='Employment Status')
plt.tight_layout()
plt.show()

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset (replace this with your actual data)
df_data = {
    'EmploymentStatus': ['Employed', 'Employed', 'Unemployed', 'Unemployed', 'Employed', 'Unemployed', 'Employed', 'Unemployed'],
    'StudyHoursCategory': ['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Medium', 'Medium']
}

df = pd.DataFrame(data)

# Frequency table for EmploymentStatus
print("Frequency Table: EmploymentStatus\n")
print(df['EmploymentStatus'].value_counts())

# Univariate bar plot for Employment Status
plt.figure(figsize=(6, 4))
sns.countplot(x='EmploymentStatus', data=df, palette='pastel')
plt.title('Distribution of Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Frequency table for StudyHoursCategory
print("\nFrequency Table: StudyHoursCategory\n")
print(df['StudyHoursCategory'].value_counts())

# Univariate bar plot for Study Hours Category
plt.figure(figsize=(6, 4))
sns.countplot(x='StudyHoursCategory', data=df, palette='pastel')
plt.title('Distribution of Study Hours')
plt.xlabel('Study Hours Category')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# Frequency table: Employment Status
print("Frequency Table - Employment Status:\n")
print(df['EmploymentStatus'].value_counts())

# Bar plot: Employment Status
plt.figure(figsize=(5, 4))
sns.countplot(x='EmploymentStatus', data=df, palette='pastel')
plt.title('Distribution of Employment Status')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Frequency table: Study Hours
print("\nFrequency Table - Study Hours:\n")
print(df['StudyHoursCategory'].value_counts())

# Bar plot: Study Hours
plt.figure(figsize=(5, 4))
sns.countplot(x='StudyHoursCategory', data=df, palette='pastel')
plt.title('Distribution of Study Hours')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# Univariate

# %%
# Install required libraries (if running in Colab)
# !pip install pandas seaborn matplotlib --quiet

# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample dataset — replace this with your real data
data = {
    'EmploymentStatus': ['Employed', 'Employed', 'Unemployed', 'Unemployed', 'Employed', 'Unemployed', 'Employed', 'Unemployed'],
    'StudyHoursCategory': ['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Medium', 'Medium']
}

df = pd.DataFrame(data)

# === UNIVARIATE ANALYSIS ===

# Frequency table: Employment Status
print("Frequency Table - Employment Status:\n")
print(df['EmploymentStatus'].value_counts())

# Bar plot: Employment Status
plt.figure(figsize=(5, 4))
sns.countplot(x='EmploymentStatus', data=df, palette='pastel')
plt.title('Distribution of Employment Status')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# Frequency table: Study Hours
print("\nFrequency Table - Study Hours:\n")
print(df['StudyHoursCategory'].value_counts())

# Bar plot: Study Hours
plt.figure(figsize=(5, 4))
sns.countplot(x='StudyHoursCategory', data=df, palette='pastel')
plt.title('Distribution of Study Hours')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# Bivariate

# %%
# === BIVARIATE ANALYSIS ===

# Cross-tab between Employment Status and Study Hours
print("\nCross-Tabulation (Employment Status vs Study Hours):\n")
cross_tab = pd.crosstab(df['EmploymentStatus'], df['StudyHoursCategory'])
print(cross_tab)

# Bar plot: Study Hours by Employment Status
plt.figure(figsize=(6, 5))
sns.countplot(x='StudyHoursCategory', hue='EmploymentStatus', data=df, palette='Set2')
plt.title('Study Hours by Employment Status')
plt.xlabel('Study Hours Category')
plt.ylabel('Count')
plt.legend(title='Employment Status')
plt.tight_layout()
plt.show()

# %% [markdown]
# Categorical Univariate Statistics and Graphs

# %%
# Sample data (you can replace this with your own)
data = {
    'EmploymentStatus': ['Employed', 'Employed', 'Unemployed', 'Unemployed', 'Employed', 'Unemployed', 'Employed', 'Unemployed'],
    'StudyHoursCategory': ['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Medium', 'Medium']
}

df = pd.DataFrame(data)

# Univariate bar plot for Employment Status
plt.figure(figsize=(6, 4))
sns.countplot(x='EmploymentStatus', data=df, palette='pastel')
plt.title('Distribution of Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# Univariate bar plot for Study Hours Category
plt.figure(figsize=(6, 4))
sns.countplot(x='StudyHoursCategory', data=df, palette='pastel')
plt.title('Distribution of Study Hours')
plt.xlabel('Study Hours Category')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
df['employed'].describe()

# %% [markdown]
# **Numerical Univariate Statistics and Graphs**

# %%
pip install researchpy

# %%
df.groupby('work_status')['credit'].describe()

# %%
df.groupby('work_status')['study_hours'].describe()

# %%
pip install researchpy

# %%
import researchpy as rp

# %%
rp.summary_cont(df.groupby(' employed')['study_hours'])

# %%
from seaborn.distributions import kdeplot
sns.displot(x='study_hours', col = ' employed' , data = df)

# %%
# Alternatively, you can create a pie chart
frequency_table.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title("employee Distribution")

# %%
df[' employed'].value_counts(normalize=True).round(2).plot(kind = 'bar', color="orange")

# %%
# Alternatively, you can create a bar chart
plt.figure(figsize=(8, 6))
frequency_counts = df['employed'].value_counts()
frequency_counts.plot(kind='bar')
plt.title('Distribution of Employed')
plt.xlabel('Employment Status')
plt.ylabel('study_hours')
plt.show()

# %%
plt.figure(figsize=(8, 6))
frequency_counts = df.groupby('study_hours')['employed'].value_counts()
frequency_counts

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create DataFrame from the data
data = {
    'employed': ['Yes', 'No', 'Yes', 'No'],
    'study_hours': [10, 15, 8, 20]  # Added study_hours data
}
df = pd.DataFrame(data)

# Create box plot
plt.figure(figsize=(8, 6))
df.boxplot(column='study_hours', by='employed')
plt.title('Study Hours Distribution by Employment Status')
plt.suptitle('')  # Remove automatic suptitle
plt.xlabel('Employment Status')
plt.ylabel('Study Hours')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create DataFrame from the data
data = {
    'employed': ['Yes', 'No', 'Yes', 'No']
}
df = pd.DataFrame(data)

# Count the frequency of each work status
employed_counts = df['employed'].value_counts()

# %%
# Import required library
import pandas as pd

# Create frequency table
frequency_table = df['employed'].value_counts()  # Removed extra space before 'employed'


# Optional: Add percentage distribution
print("\nPercentage Distribution:")
print("-" * 35)
print(frequency_table / len(df) * 100, "%")

# %%
df["study_hours"].value_counts()

# %%
# Frequency table
frequency_table = df['work_status'].value_counts()
print(frequency_table)

# Import required library
import pandas as pd

# Create frequency table
frequency_table = df['work_status'].value_counts()

# Display results
print("\nFrequency Table for Work Status:")
print(frequency_table)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create DataFrame from the data
data = {
    'employed': ['Yes', 'No', 'Yes',  'No']
}
df = pd.DataFrame(data)

# Count the frequency of each work status
work_status_counts = df['employed'].value_counts()

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(work_status_counts, labels=work_status_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Work Status')
plt.axis('equal')
plt.show()

# %%
# Import required libraries
import researchpy as rp
import pandas as pd

# Calculate summary statistics
stats = rp.summary_df['study_hours'])

# Display results with clear formatting
print("\nSummary Statistics for Study Hours:")
print(stats)

# %% [markdown]
# # 2 Sample t **Analysis**

# %% [markdown]
# # **Bivariate Comparision Statistics**

# %% [markdown]
# # **Bivariate Graphs**

# %% [markdown]
# # **Check Normality**

# %% [markdown]
# # **2 Sample t Test**

# %% [markdown]
# # **# Moderation Analysis**
