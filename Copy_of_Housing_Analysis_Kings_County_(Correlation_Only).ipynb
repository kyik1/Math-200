# %% [markdown]
# <a href="https://colab.research.google.com/github/kyik1/Math-200/blob/main/Copy_of_Housing_Analysis_Kings_County_(Correlation_Only).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = 'https://raw.githubusercontent.com/kmath22/kmath22/main/KC%20(Kings%20country%20Wash)%20housing%20data.csv'

kings_df = pd.read_csv(data)

kings_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
#Scatterplot of Bedrooms vs price
sns.scatterplot(x = 'bedrooms' , y = 'price' , data = kings_df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
#Scatterplot of bathrooms vs price

# %%
#Scatterplot of Square ft living area vs price

# %%
#Scatterplot of Square ft loft size vs price

# %%
#Correlation Table
kings_df.corr(numeric_only=True)
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016797  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016797  1.000000  0.308338   0.525134     0.702044  0.089655
# bedrooms       0.001286  0.308338  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525134  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702044  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089655  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256786  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266331 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397346  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036392  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667463  0.356967   0.664983     0.762704  0.113621
# ...

# %% [markdown]
# # Part #2

# %%
#Summary statistics Bedrooms and price (Summary statistics)
kings_df.groupby('bedrooms')['price'].agg(['mean','median','std']).round()
# Out:
#                mean    median       std
# bedrooms
# 0          410223.0  288000.0  360375.0
# 1          317658.0  299000.0  148960.0
# 2          401388.0  374000.0  198129.0
# 3          466277.0  413000.0  262621.0
# 4          635565.0  549998.0  388901.0
# 5          786874.0  620000.0  596537.0
# 6          825854.0  650000.0  799610.0
# 7          951448.0  728580.0  740350.0
# 8         1105077.0  700000.0  897496.0
# 9          894000.0  817000.0  381534.0
# 10         820000.0  660000.0  285832.0
# 11         520000.0  520000.0       NaN
# 33         640000.0  640000.0       NaN

# %%
sns.boxplot(x = 'bedrooms' , y ='price', data = kings_df, showmeans =True)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %%
#Fill in the lon and lat
fig = px.scatter_mapbox(kings_df,
                        lon = kings_df['long'],
                        lat = kings_df['lat'],
                        zoom = 5,
                        color = kings_df['price'],
                        width = 1200,
                        height = 900,
                        title = 'Kings County Home Prices',
                        )

fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(margin = {"r":0, "t":50})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-eb78f5a6544c> in <cell line: 0>()
#       1 #Fill in the lon and lat
# ----> 2 fig = px.scatter_mapbox(kings_df,
#       3                         lon = kings_df['long'],
#       4                         lat = kings_df['lat'],
#       5                         zoom = 5,
#
# NameError: name 'px' is not defined

# %%
#Import plotly for maps
import plotly.express as px

# %%
#Fill in the lon and lat
fig = px.scatter_mapbox(kings_df,
                        lon = kings_df['long']  ,
                        lat = kings_df['lat']  ,
                        zoom = 12,
                        color = kings_df['price'],
                        width = 1200,
                        height = 900,
                        title = 'Kings County Home Prices',
                        )

fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(margin = {"r":0, "t":50})


fig.show()
